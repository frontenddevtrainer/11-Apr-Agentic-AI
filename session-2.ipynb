# %% [markdown]
# LangChain Expression Language (LCEL)
#
# LCEL is LangChain's declarative way to compose chains using the pipe (|) operator. It provides:
#
# A consistent interface (invoke, stream, batch)
# Easy composition of prompts, models, parsers, and custom functions
# Built-in streaming and async support
# This notebook covers LCEL patterns from basic to advanced.

# %%
# !pip install -q langchain langchain-openai langchain-anthropic langchain-google-genai python-dotenv

# %%
from dotenv import load_dotenv

load_dotenv()  # Loads OPENAI_API_KEY, ANTHROPIC_API_KEY, GOOGLE_API_KEY from .env

from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# We'll use these models throughout
openai_llm = ChatOpenAI(model="gpt-4o", temperature=0.7)
# anthropic_llm = ChatAnthropic(model="claude-sonnet-4-20250514", temperature=0.7)
# gemini_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.7)

# %% [markdown]
# 1. Basic Chain: Prompt | Model | Parser
#
# The fundamental LCEL pattern. The | operator pipes the output of one component into the next.
#
# prompt → model → output_parser

# %%
# Basic LCEL chain: prompt | model | parser
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "{question}")
])

# Chain components together with the pipe operator
chain = prompt | openai_llm | StrOutputParser()

# invoke() takes the prompt's input variables as a dict
result = chain.invoke({"question": "What is LCEL in LangChain?"})
print(result)
# Out:
# In LangChain, LCEL stands for "LangChain Expression Language". It is a domain-specific language designed to allow users to define and compose expressions in a flexible and powerful way. LCEL is used within the LangChain framework to facilitate the creation and manipulation of various language model-based applications. It enables users to express complex logic and workflows succinctly, often used in the context of chaining different language models and processing steps together.
#
# LCEL is part of the broader LangChain ecosystem, which is a framework for developing applications that leverage large language models (LLMs). LangChain provides tools and abstractions for working with LLMs, including prompt management, chaining of operations, and integration with external data sources and APIs.
#
# Overall, LCEL is a key component in LangChain that helps users define complex operations and workflows in an intuitive and efficient manner.
